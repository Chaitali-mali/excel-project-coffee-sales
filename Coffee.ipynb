# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\chait\Downloads\coffeeOrdersData.csv")

# %%
df
# Out:
#    Product ID Coffee Type Roast Type  Size  Unit Price  Price per 100g  \
# 0     A-L-0.2         Ara          L   0.2       3.885          1.9425
# 1     A-L-0.5         Ara          L   0.5       7.770          1.5540
# 2       A-L-1         Ara          L   1.0      12.950          1.2950
# 3     A-L-2.5         Ara          L   2.5      29.785          1.1914
# 4     A-M-0.2         Ara          M   0.2       3.375          1.6875
# 5     A-M-0.5         Ara          M   0.5       6.750          1.3500
# 6       A-M-1         Ara          M   1.0      11.250          1.1250
# 7     A-M-2.5         Ara          M   2.5      25.875          1.0350
# 8     A-D-0.2         Ara          D   0.2       2.985          1.4925
# 9     A-D-0.5         Ara          D   0.5       5.970          1.1940
# 10      A-D-1         Ara          D   1.0       9.950          0.9950
# 11    A-D-2.5         Ara          D   2.5      22.885          0.9154
# ...

# %%
df.shape
# Out:
# (48, 7)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of    Product ID Coffee Type Roast Type  Size  Unit Price  Price per 100g  \
# 0     A-L-0.2         Ara          L   0.2       3.885          1.9425
# 1     A-L-0.5         Ara          L   0.5       7.770          1.5540
# 2       A-L-1         Ara          L   1.0      12.950          1.2950
# 3     A-L-2.5         Ara          L   2.5      29.785          1.1914
# 4     A-M-0.2         Ara          M   0.2       3.375          1.6875
# 5     A-M-0.5         Ara          M   0.5       6.750          1.3500
# 6       A-M-1         Ara          M   1.0      11.250          1.1250
# 7     A-M-2.5         Ara          M   2.5      25.875          1.0350
# 8     A-D-0.2         Ara          D   0.2       2.985          1.4925
# 9     A-D-0.5         Ara          D   0.5       5.970          1.1940
# 10      A-D-1         Ara          D   1.0       9.950          0.9950
# 11    A-D-2.5         Ara          D   2.5      22.885          0.9154
# ...

# %%
df.tail
# Out:
# <bound method NDFrame.tail of    Product ID Coffee Type Roast Type  Size  Unit Price  Price per 100g  \
# 0     A-L-0.2         Ara          L   0.2       3.885          1.9425
# 1     A-L-0.5         Ara          L   0.5       7.770          1.5540
# 2       A-L-1         Ara          L   1.0      12.950          1.2950
# 3     A-L-2.5         Ara          L   2.5      29.785          1.1914
# 4     A-M-0.2         Ara          M   0.2       3.375          1.6875
# 5     A-M-0.5         Ara          M   0.5       6.750          1.3500
# 6       A-M-1         Ara          M   1.0      11.250          1.1250
# 7     A-M-2.5         Ara          M   2.5      25.875          1.0350
# 8     A-D-0.2         Ara          D   0.2       2.985          1.4925
# 9     A-D-0.5         Ara          D   0.5       5.970          1.1940
# 10      A-D-1         Ara          D   1.0       9.950          0.9950
# 11    A-D-2.5         Ara          D   2.5      22.885          0.9154
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of    Product ID Coffee Type Roast Type  Size  Unit Price  Price per 100g  \
# 0     A-L-0.2         Ara          L   0.2       3.885          1.9425
# 1     A-L-0.5         Ara          L   0.5       7.770          1.5540
# 2       A-L-1         Ara          L   1.0      12.950          1.2950
# 3     A-L-2.5         Ara          L   2.5      29.785          1.1914
# 4     A-M-0.2         Ara          M   0.2       3.375          1.6875
# 5     A-M-0.5         Ara          M   0.5       6.750          1.3500
# 6       A-M-1         Ara          M   1.0      11.250          1.1250
# 7     A-M-2.5         Ara          M   2.5      25.875          1.0350
# 8     A-D-0.2         Ara          D   0.2       2.985          1.4925
# 9     A-D-0.5         Ara          D   0.5       5.970          1.1940
# 10      A-D-1         Ara          D   1.0       9.950          0.9950
# 11    A-D-2.5         Ara          D   2.5      22.885          0.9154
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Product ID      48 non-null     object
#  1   Coffee Type     48 non-null     object
#  2   Roast Type      48 non-null     object
#  3   Size            48 non-null     float64
#  4   Unit Price      48 non-null     float64
#  5   Price per 100g  48 non-null     float64
#  6   Profit          48 non-null     float64
# dtypes: float64(4), object(3)
# memory usage: 2.8+ KB

# %%
df.dtypes
# Out:
# Product ID         object
# Coffee Type        object
# Roast Type         object
# Size              float64
# Unit Price        float64
# Price per 100g    float64
# Profit            float64
# dtype: object

# %%
df.mean
# Out:
# <bound method DataFrame.mean of    Product ID Coffee Type Roast Type  Size  Unit Price  Price per 100g  \
# 0     A-L-0.2         Ara          L   0.2       3.885          1.9425
# 1     A-L-0.5         Ara          L   0.5       7.770          1.5540
# 2       A-L-1         Ara          L   1.0      12.950          1.2950
# 3     A-L-2.5         Ara          L   2.5      29.785          1.1914
# 4     A-M-0.2         Ara          M   0.2       3.375          1.6875
# 5     A-M-0.5         Ara          M   0.5       6.750          1.3500
# 6       A-M-1         Ara          M   1.0      11.250          1.1250
# 7     A-M-2.5         Ara          M   2.5      25.875          1.0350
# 8     A-D-0.2         Ara          D   0.2       2.985          1.4925
# 9     A-D-0.5         Ara          D   0.5       5.970          1.1940
# 10      A-D-1         Ara          D   1.0       9.950          0.9950
# 11    A-D-2.5         Ara          D   2.5      22.885          0.9154
# ...

# %%
df.max
# Out:
# <bound method DataFrame.max of    Product ID Coffee Type Roast Type  Size  Unit Price  Price per 100g  \
# 0     A-L-0.2         Ara          L   0.2       3.885          1.9425
# 1     A-L-0.5         Ara          L   0.5       7.770          1.5540
# 2       A-L-1         Ara          L   1.0      12.950          1.2950
# 3     A-L-2.5         Ara          L   2.5      29.785          1.1914
# 4     A-M-0.2         Ara          M   0.2       3.375          1.6875
# 5     A-M-0.5         Ara          M   0.5       6.750          1.3500
# 6       A-M-1         Ara          M   1.0      11.250          1.1250
# 7     A-M-2.5         Ara          M   2.5      25.875          1.0350
# 8     A-D-0.2         Ara          D   0.2       2.985          1.4925
# 9     A-D-0.5         Ara          D   0.5       5.970          1.1940
# 10      A-D-1         Ara          D   1.0       9.950          0.9950
# 11    A-D-2.5         Ara          D   2.5      22.885          0.9154
# ...

# %% [markdown]
# ### Total Product ID :

# %%
print("Total Product ID  Amount:", df['Product ID'].sum())
# Out:
# Total Product ID  Amount: A-L-0.2A-L-0.5A-L-1A-L-2.5A-M-0.2A-M-0.5A-M-1A-M-2.5A-D-0.2A-D-0.5A-D-1A-D-2.5R-L-0.2R-L-0.5R-L-1R-L-2.5R-M-0.2R-M-0.5R-M-1R-M-2.5R-D-0.2R-D-0.5R-D-1R-D-2.5L-L-0.2L-L-0.5L-L-1L-L-2.5L-M-0.2L-M-0.5L-M-1L-M-2.5L-D-0.2L-D-0.5L-D-1L-D-2.5E-L-0.2E-L-0.5E-L-1E-L-2.5E-M-0.2E-M-0.5E-M-1E-M-2.5E-D-0.2E-D-0.5E-D-1E-D-2.5

# %% [markdown]
# ###  Most Popular Coffee:

# %%
print(df['Coffee Type'].value_counts().head())
# Out:
# Coffee Type
# Ara    12
# Rob    12
# Lib    12
# Exc    12
# Name: count, dtype: int64
